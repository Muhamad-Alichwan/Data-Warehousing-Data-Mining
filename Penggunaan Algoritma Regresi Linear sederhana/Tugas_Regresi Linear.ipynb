# %%
#Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Real estate.csv')
df.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
price_unit_area = df['Y house price of unit area'].groupby(df['X2 house age']).sum().sort_values(ascending = True)
f, ax = plt.subplots(1,1,figsize=(8,6)) 
ax = sns.barplot(x = price_unit_area.head(), y = price_unit_area.head().index, palette='Blues')

# %%
f, ax = plt.subplots(1,1,figsize=(12,8)) 
ax = sns.barplot(x='X2 house age' , y= 'Y house price of unit area', hue= 'X4 number of convenience stores', data = df)

# %%
ax = sns.lmplot(x='X3 distance to the nearest MRT station' , y= 'Y house price of unit area', hue= 'X4 number of convenience stores', data = df, palette ='Set1')
ax = sns.lmplot(x='X1 transaction date' , y= 'Y house price of unit area', hue= 'X4 number of convenience stores', data = df, palette ='Set2')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
from sklearn.model_selection import train_test_split as holdout
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
x = df.drop(['Y house price of unit area'], axis=1)
y = df['Y house price of unit area']
X_train, X_test, y_train, y_test = holdout(x,y, test_size= 0.2, random_state=0)

# %%
linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_reg.predict(X_test)

# %%
R2 = metrics.r2_score(y_test, y_pred)
rmse = (np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2 : {0:.3f}'.format(R2))
print('RMSE : {0:.3f}'.format(rmse))
# Out:
# R2 : 0.656
# RMSE : 7.733

# %%
importance = linear_reg.coef_
variables = ['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longitude']
for i, v in zip(variables,importance):
    print('Feature: %s, Score: %.5f'%(i,v))
# Out:
# Feature: X1 transaction date, Score: -0.00446
# Feature: X2 house age, Score: 4.87352
# Feature: X3 distance to the nearest MRT station, Score: -0.26278
# Feature: X4 number of convenience stores, Score: -0.00452
# Feature: X5 latitude, Score: 1.08106
# Feature: X6 longitude, Score: 226.07761

# %% [markdown]
# ## setelah mengeliminasi fitur yang tidak berpengaruh

# %%
x_2 = df.drop(['Y house price of unit area','X1 transaction date','X3 distance to the nearest MRT station','X4 number of convenience stores'], axis=1)
y_2 = df['Y house price of unit area']
X_train_2, X_test_2, y_train_2, y_test_2 = holdout(x_2,y_2, test_size= 0.2, random_state=0)

# %%
linear_reg_2 = LinearRegression()
linear_reg_2.fit(X_train_2, y_train_2)
# Out:
# LinearRegression()

# %%
y_pred_2 = linear_reg_2.predict(X_test_2)

# %%
R2 = metrics.r2_score(y_test_2, y_pred_2)
rmse = (np.sqrt(metrics.mean_squared_error(y_test_2, y_pred_2)))
print('R2 : {0:.3f}'.format(R2))
print('RMSE : {0:.3f}'.format(rmse))
# Out:
# R2 : 0.496
# RMSE : 9.352

# %%
importance_2 = linear_reg_2.coef_
variables_2 = ['X2 house age','X5 latitude','X6 longitude']
for i, v in zip(variables_2,importance_2):
    print('Feature: %s, Score: %.5f'%(i,v))
# Out:
# Feature: X2 house age, Score: -0.00470
# Feature: X5 latitude, Score: -0.25652
# Feature: X6 longitude, Score: 437.23516
